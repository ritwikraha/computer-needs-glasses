# %% [markdown]
# <a href="https://colab.research.google.com/github/ritwikraha/computer-needs-glasses/blob/master/image-generation/SDXL_Playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qq git+https://github.com/huggingface/diffusers.git
# !pip install -qq transformers accelerate safetensors
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 4.4 MB/s eta 0:00:00

# %%
from diffusers import DiffusionPipeline
from diffusers import EDMDPMSolverMultistepScheduler
import torch

# %%
pipe = DiffusionPipeline.from_pretrained(
    "playgroundai/playground-v2.5-1024px-aesthetic",
    torch_dtype=torch.float16,
    variant="fp16",
).to("cuda")
# Out:
# model_index.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# Fetching 18 files:   0%|          | 0/18 [00:00<?, ?it/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/704 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/497 [00:00<?, ?B/s]
# text_encoder_2/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/560 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/586 [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# tokenizer_2/special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# tokenizer_2/tokenizer_config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/1.78k [00:00<?, ?B/s]
# model.fp16.safetensors:   0%|          | 0.00/246M [00:00<?, ?B/s]
# tokenizer_2/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# ...

# %%
# pipe.scheduler = EDMDPMSolverMultistepScheduler()
prompt = "futuristic bungalow with an antique design"
negative_prompt = "bad anatomy, extra digits, ugly faces"

# %%
image = pipe(prompt=prompt,
             negative_prompt=negative_prompt,
             num_inference_steps=50,
             guidance_scale=3).images[0]
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x1024>
